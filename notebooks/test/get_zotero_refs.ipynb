# %%
from idd_manuscripts import constants as rfc
from idd_manuscripts.citation_functions import load_zotero_config, fetch_and_save_zotero_items, search_bibliography

# %%
# Fetch and save all items
user_id, api_key = load_zotero_config(rfc.zotero_config)
items = fetch_and_save_zotero_items(user_id, api_key, 'zotero_items.json')

# %%
search_bibliography(items, author="Reiner")
# Out:
# IJAJVZZY: Current dichotomous metrics obscure trends in severe and extreme child growth failure
#   Authors: Fitzgerald, Manguerra, Arndt, Gardner, Chang, Zigler, Taylor, Bienhoff, Smith, Murray, Hay, Reiner, Kassebaum
#   Year: 2022
#   Journal: Science Advances
#
# 9QUTN8PI: Global, regional, and national progress towards the 2030 global nutrition targets and forecasts to 2050: a systematic analysis for the Global Burden of Disease Study 2021
# ...
